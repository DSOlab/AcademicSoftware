# %%
# Section 1 - Imports
# -------------------

# imports
import datetime
import attotime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import math
from os.path import join
import copy

# DSO modules
from dsoclasses.doris.algorithms import beacon_nominal_frequency
from dsoclasses.rinex.doris.rinex import DorisRinex
from dsoclasses.time.pyattotime import at2pt, fsec2asec, to_attoseconds
from dsoclasses.orbits import sp3c, interpolator
from dsoclasses.geodesy import transformations
from dsoclasses.gnss import systems as gs
from dsoclasses.gnss import algorithms as alg
from dsoclasses.troposphere.vmf3 import SiteVmf3
from dsoclasses.sinex import sinex

# %%
# Section 2.1 – Define Files needed for analysis
# -----------------------------------------------

data_path = "/home/xanthos/Software/AcademicSoftware/data"
drinex = join(data_path, "s6arx24001.001")
dpod = join(data_path, "dpod2020_041.snx")
dpod_freq_corr = join(data_path, "dpod2020_041_freq_corr.txt")
dsp3 = join(data_path, "ssas6a20.b23357.e24001.DG_.sp3.001")
vmf3_data = join(data_path, "y2024.vmf3_d")

# %%
# Section 2.2 - Load Orbit Data + Initialize Interpolator
# -------------------------------------------------------

intrp = interpolator.Sp3Interpolator.from_sp3(dsp3, ['L'], interval_in_sec=310, min_data_pts=10, itype='Barycentric')

# %%
# Section 2.3 - Intitialize DorisRinex and select a beacon (Dionysos/DIOB)
# ------------------------------------------------------------------------

rnx = DorisRinex(drinex)

site_name = 'DIOB'
result = sinex.extract_sinex_coordinates(dpod, [site_name], rnx.time_first_obs, True, dpod_freq_corr)
rsta   = np.array([result['DIOB']['X'], result['DIOB']['Y'], result['DIOB']['Z']])

# we are also going to need the geodetic coordinates of the site
lat, lon, hgt = transformations.car2ell(*diob_xyz)

# %%
# Section 2.4 - Initialize VMF3 from (DORIS) site data
# ----------------------------------------------------
vmf = SiteVmf3(vmf3_data, [site_name])

# %%
# Section 3.1 - Prerequisites & helper functions
# ----------------------------------------------

C = 299792458e0

# Ionosphere-free LC for phase observables
def getL3fun(nS1, nU2):
    gamma_sqrt = nS1 / nU2
    gamma = gamma_sqrt * gamma_sqrt
    l3_freq = (gamma * nS1 - gamma_sqrt * nU2) / (gamma - 1.)
    def l3(s1, u2):
        return (gamma * s1 - gamma_sqrt * u2) / (gamma - 1.), l3_freq
    return l3

# For DIOB ...
s1, u2 = beacon_nominal_frequency(rnx.kfactor(site_name))
l3 = getL3fun(s1, u2)

class L3Obs:
    def __init__(self, t, l3, sat_pos, dT, el, feN, frT, pass_nr):
        self.t = t
        self.val = l3
        self.rsat = sat_pos
        self.Tropo = dT
        self.el = el
        self.feN = feN
        self.frT = frT
        self.pass_nr = pass_nr
    def dTropo(self, zwd=None):
        zwd = self.Tropo['zwd'] if zwd is None else zwd
        d = self.Tropo
        return d["zhd"] * d["mfh"] + d["zwd"] * d["mfw"]

class DopplerObs:
    def __init__(self, l3t1, l3t2):
        self.l3t1 = copy.deepcopy(l3t1)
        self.l3t2 = copy.deepcopy(l3t2)
        assert self.l3t1.feN == self.l3t2.feN
        assert self.l3t1.pass_nr == self.l3t2.pass_nr
    def feN(self): return self.l3t1.feN
    def frT(self): return (self.l3t1.frT + self.l3t2.frT) / 2.
    def Ncount(self): return self.l3t2.val - self.l3t1.val
    def dt(self): # returns t2-t1 in [seconds]
        return float((self.l3t2.t-self.l3t1.t).total_nanoseconds()) * 1e-9
    def ttai(self): 
        return self.l3t1.t + (self.l3t2.t-self.l3t1.t) // 2
    def Ndoppler(self): return self.Ncount() / self.dt()
    def elevation(self): return (self.l3t1.el + self.l3t2.el) / 2.
    def pass_nr(self): return self.l3t1.pass_nr
    def r1(self, rsta): return np.linalg.norm(self.l3t1.rsat - rsta)
    def r2(self, rsta): return np.linalg.norm(self.l3t2.rsat - rsta)
    def rsat1(self): return self.l3t1.rsat
    def rsat2(self): return self.l3t2.rsat
    def observed_rr(self):
        # return (C/self.feN()) * (self.feN() - self.frT() - self.Ndoppler()) # + (self.l3t2.dT - self.l3t1.dT)
        return -(C/self.feN()) * (self.feN() - self.frT() - self.Ndoppler())
    def computed_rr(self, rsta, df, zwd):
        dT = self.l3t2.dTropo(zwd) - self.l3t1.dTropo(zwd)
        return (self.r2(rsta) - self.r1(rsta)) / self.dt() # + dT # - (C/self.feN()) * (self.Ndoppler()+self.frT()) * df
    def ddzwd(self):
        return self.l3t2.Tropo['mfw'] - self.l3t1.Tropo['mfw']
    def apriori_zwd(self): return (self.l3t2.Tropo['zwd'] + self.l3t1.Tropo['zwd']) / 2.
    def set_pass_nr(self, nr):
        self.l3t1.pass_nr = nr
        self.l3t2.pass_nr = nr

# %%
# Section 3.2 - Initialize variables
# ----------------------------------

tprev   = None # previous (to current) observation epoch
L3_prev = None # previous L3 observation
CUTOFF_ANGLE = np.radians(7.) # Elevation cut-off angle
doppler = []    # Doppler observations collected
pass_nr = 0    # satellite pass number
tai_prev = None # time of previous obs, to count passes
passes_start_indexes = {} # start index in doppler list for every pass

# %%
# Section 4 – Preprocess Doppler observations (filter valid ones for LS)
# ----------------------------------------------------------------------

# Just checking that the above block is restarted before continuing ...
assert pass_nr == 0

# for every block in the RINEX file
for block in rnx:
    # for every beacon in the block
    for beacon, data in block:
        # match DIOB
        if beacon == rnx.name2id(site_name):
            
            # use the block-provided clock correction to get to (approximate) TAI
            # date(TAI) = epoch + receiver clock offset
            tai = block.t() + attotime.attotimedelta(nanoseconds=block.clock_offset() * 1e9)

            # see if we have a new pass
            if (tai_prev is None or (tai-tai_prev).total_seconds() > 600.) and len(doppler)!=0:
                pass_nr += 1
                passes_start_indexes[pass_nr] = len(doppler)
            tai_prev = tai
            
            # Satellite position at signal emission time
            satx, saty, satz, _, _ = alg.sat_at_emission_time(diob_xyz, tai, intrp, 'L40')
            rsat = np.array([satx, saty, satz])

            # Elevation and tropospheric delay
            _, _, el = transformations.azele(rsat, diob_xyz)
            if el >= CUTOFF_ANGLE:
                Tropo = vmf.tropo_dealy_info(site_name, lat, lon, el, at2pt(tai))
    
                # Phase measurements L3 combination
                L3, L3f = l3(data['L1']['value'], data['L2']['value'])
    
                # apply frequency offset - get true receiver frequency
                frT = L3f * (1 + data['F']['value'] * 1e-11)

                # form the new observation
                L3_cur = L3Obs(tai, L3, rsat, Tropo, el, L3f, frT, pass_nr)
    
                # if we have a previous measurement, within 10 sec ...
                if L3_prev is not None and (L3_cur.t-L3_prev.t).total_seconds() <= 10.:
                    doppler.append(DopplerObs(L3_prev, L3_cur))

                # prepare for next measurement
                L3_prev = L3_cur
                    
print(f"Number of Doppler observations extracted: {len(doppler)}")
# Out:
# Number of Doppler observations extracted: 965

# %%
# Section 4.1 - Examine passes
# ----------------------------

passes_info = {}
for data in doppler:
    ps = data.pass_nr()
    if ps in passes_info:
        passes_info[ps] += 1
    else:
        passes_info[ps] = 1
print('Number of data per pass:')
for k,v in passes_info.items():
    print(f'Pass {k} Data {v}')
for k,v in passes_start_indexes.items():
    print(f'Pass {k} start_index {v}')
# Out:
# Number of data per pass:
# Pass 0 Data 153
# Pass 1 Data 198
# Pass 2 Data 118
# Pass 3 Data 4
# Pass 4 Data 142
# Pass 5 Data 198
# Pass 6 Data 152
# Pass 1 start_index 153
# Pass 2 start_index 351
# Pass 3 start_index 469
# Pass 4 start_index 473
# Pass 5 start_index 615
# Pass 6 start_index 813

# %%
MIN_DATA_PTS_IN_PASS = 10

def build_pass_starts(doppler):
    """Return {pass_id: start_index} from the doppler list."""
    starts = {}
    if not doppler:
        return starts
    cur = doppler[0].pass_nr()
    starts[cur] = 0
    for i in range(1, len(doppler)):
        pn = doppler[i].pass_nr()
        if pn != cur:
            starts[pn] = i
            cur = pn
    return starts

data_removed = True
while data_removed:
    data_removed = False  # reset each pass
    starts = build_pass_starts(doppler)
    if not starts:
        break

    pass_ids = sorted(starts.keys())
    for idx, pid in enumerate(pass_ids):
        start = starts[pid]
        end = starts[pass_ids[idx + 1]] if idx + 1 < len(pass_ids) else len(doppler)
        num_pts = end - start

        if num_pts < MIN_DATA_PTS_IN_PASS:
            print(f"Should remove pass {pid} from {start} to {end}")
            # remove the slice
            del doppler[start:end]
            # renumber subsequent entries
            for j in range(start, len(doppler)):
                if doppler[j].pass_nr() > pid:
                    doppler[j].set_pass_nr(doppler[j].pass_nr() - 1)
            data_removed = True
            break  # restart while-loop with rebuilt starts
# Out:
# Should remove pass 3 from 469 to 473

# %%
# Section 5 – Weighted Least Squares Solution
# --------------------------------------------

Np = pass_nr + 1 # Number of passes

# Initial guess: [x, y, z, Δf, ΔT_pass1, ΔT_pass2, ..., ΔT_passN]
x0 = np.zeros(3) # parameter vector
x0[0:3] = diob_xyz         # start with nominal beacon position
# a-priori ZWD, per pass
#x0[3+Np] = doppler[0].apriori_zwd()
#for j in range(1, len(doppler)-1):
#    if doppler[j].pass_nr() != doppler[j-1].pass_nr():
#        x0[3+Np+doppler[j].pass_nr()] = doppler[j].apriori_zwd()
#        print(f'-> adding ZWD for pass={doppler[j].pass_nr()}, j={j}')
#        assert (3+Np+doppler[j].pass_nr()) < (3+Np+Np)
        
x = x0.copy()
tai0 = doppler[0].ttai()

m = len(doppler)           # number of valid Doppler observations
J = np.zeros((m, len(x0))) # Jacobian matrix (design matrix)
dl = np.zeros(m)           # residual vector (observed - modeled)

sigma0 = .5                # sigma 0 in [m/sec]
elvs = np.array([obs.elevation() for obs in doppler]) # elevations arrays
sigma_i = sigma0 / np.sin(elvs)                      # per-observation stdev
sqrt_w = 1.0 / sigma_i                               # = sqrt(w_i)
W = sqrt_w**2                                        # = 1/sigma_i^2

LS_ITERATIONS = 1             # number of least squares iterations

for ls_iteration in range(LS_ITERATIONS):
    J = np.zeros((m, len(x)))
    dl = np.zeros(m)
    for i, obs in enumerate(doppler):
        dt = float((obs.ttai()-tai0).total_nanoseconds()) * 1e-9

        # Current parameter estimates
        r_beacon = x[0:3]               # beacon position estimate
        pass_id = obs.pass_nr()
        #df      = x[3 + pass_id]        # frequency bias
        #zwd     = x[3 + Np + pass_id]   # zwd
        
        # residual (observed - modeled), UNWEIGHTED
        dl[i] = obs.observed_rr() - obs.computed_rr(r_beacon, 0e0, None)
        
        if abs(dl[i]) > 10.0:
            print(f"Skipping obs {i} due to large residual: {dl[i]:+.3f} m/s")
            sqrt_w[i] = 0.0
            continue

        # Jacobian Matrix
        J[i, 0:3] = (r_beacon - obs.rsat2()) / (obs.r2(r_beacon) * obs.dt()) - (r_beacon - obs.rsat1()) / (obs.r1(r_beacon) * obs.dt())
        # J[i, 3 + pass_id] = +1.0
        # J[i, 3 + Np + pass_id] = obs.ddzwd()
        
        
    Jw  = J * sqrt_w[:, None]      # each row scaled by sqrt(w_i)
    dlw = dl * sqrt_w              # same scaling for rhs

    # least squares solution
    dx, *_ = np.linalg.lstsq(Jw, dlw, rcond=None)
    x += dx

    # Posterior sigma of unit weight (scalar)
    dof = m - len(x)
    sigma_hat0 = np.sqrt(np.sum(dlw**2) / dof)   # == sqrt(sum(w*dl**2)/dof)

# de-weight residuals
dl_unweighted = np.divide(dlw, sqrt_w, out=np.zeros_like(dlw), where=sqrt_w!=0)
# Out:
# Skipping obs 0 due to large residual: -10274.273 m/s
# Skipping obs 1 due to large residual: -10247.369 m/s
# Skipping obs 2 due to large residual: -10219.759 m/s
# Skipping obs 3 due to large residual: -10191.210 m/s
# Skipping obs 4 due to large residual: -10161.920 m/s
# Skipping obs 5 due to large residual: -10131.642 m/s
# Skipping obs 6 due to large residual: -10100.589 m/s
# Skipping obs 7 due to large residual: -10068.496 m/s
# Skipping obs 8 due to large residual: -10035.589 m/s
# Skipping obs 9 due to large residual: -10001.592 m/s
# Skipping obs 10 due to large residual: -9966.738 m/s
# Skipping obs 11 due to large residual: -9930.739 m/s
# Skipping obs 12 due to large residual: -9893.839 m/s
# Skipping obs 13 due to large residual: -9855.734 m/s
# Skipping obs 14 due to large residual: -9816.683 m/s
# Skipping obs 15 due to large residual: -9776.368 m/s
# Skipping obs 16 due to large residual: -9735.058 m/s
# Skipping obs 17 due to large residual: -9692.417 m/s
# Skipping obs 18 due to large residual: -9648.733 m/s
# Skipping obs 19 due to large residual: -9603.650 m/s
# Skipping obs 20 due to large residual: -9557.470 m/s
# Skipping obs 21 due to large residual: -9509.819 m/s
# Skipping obs 22 due to large residual: -9461.018 m/s
# Skipping obs 23 due to large residual: -9410.669 m/s
# Skipping obs 24 due to large residual: -9359.110 m/s
# Skipping obs 25 due to large residual: -9305.929 m/s
# Skipping obs 26 due to large residual: -9251.476 m/s
# Skipping obs 27 due to large residual: -9195.319 m/s
# Skipping obs 28 due to large residual: -9137.827 m/s
# Skipping obs 29 due to large residual: -9078.546 m/s
# Skipping obs 30 due to large residual: -9017.863 m/s
# Skipping obs 31 due to large residual: -8955.305 m/s
# Skipping obs 32 due to large residual: -8891.277 m/s
# Skipping obs 33 due to large residual: -8825.282 m/s
# Skipping obs 34 due to large residual: -8757.748 m/s
# Skipping obs 35 due to large residual: -8688.153 m/s
# Skipping obs 36 due to large residual: -8616.945 m/s
# Skipping obs 37 due to large residual: -8543.583 m/s
# Skipping obs 38 due to large residual: -8468.532 m/s
# Skipping obs 39 due to large residual: -8391.230 m/s
# Skipping obs 40 due to large residual: -8312.165 m/s
# Skipping obs 41 due to large residual: -8230.749 m/s
# Skipping obs 42 due to large residual: -8147.495 m/s
# Skipping obs 43 due to large residual: -8061.787 m/s
# Skipping obs 44 due to large residual: -7974.167 m/s
# Skipping obs 45 due to large residual: -7883.997 m/s
# Skipping obs 46 due to large residual: -7791.835 m/s
# Skipping obs 47 due to large residual: -7697.025 m/s
# Skipping obs 48 due to large residual: -7600.151 m/s
# Skipping obs 49 due to large residual: -7500.531 m/s
# Skipping obs 50 due to large residual: -7398.777 m/s
# Skipping obs 51 due to large residual: -7294.183 m/s
# Skipping obs 52 due to large residual: -7187.386 m/s
# Skipping obs 53 due to large residual: -7077.663 m/s
# Skipping obs 54 due to large residual: -6965.673 m/s
# Skipping obs 55 due to large residual: -6850.677 m/s
# Skipping obs 56 due to large residual: -6733.356 m/s
# Skipping obs 57 due to large residual: -6612.957 m/s
# Skipping obs 58 due to large residual: -6490.182 m/s
# Skipping obs 59 due to large residual: -6364.271 m/s
# Skipping obs 60 due to large residual: -6235.940 m/s
# Skipping obs 61 due to large residual: -6104.426 m/s
# Skipping obs 62 due to large residual: -5970.463 m/s
# Skipping obs 63 due to large residual: -5833.284 m/s
# Skipping obs 64 due to large residual: -5693.637 m/s
# Skipping obs 65 due to large residual: -5550.761 m/s
# Skipping obs 66 due to large residual: -5405.415 m/s
# Skipping obs 67 due to large residual: -5256.845 m/s
# Skipping obs 68 due to large residual: -5105.817 m/s
# Skipping obs 69 due to large residual: -4951.595 m/s
# Skipping obs 70 due to large residual: -4794.946 m/s
# Skipping obs 71 due to large residual: -4635.157 m/s
# Skipping obs 72 due to large residual: -4472.994 m/s
# Skipping obs 73 due to large residual: -4307.768 m/s
# Skipping obs 74 due to large residual: -4140.242 m/s
# Skipping obs 75 due to large residual: -3969.764 m/s
# Skipping obs 76 due to large residual: -3797.079 m/s
# Skipping obs 77 due to large residual: -3621.582 m/s
# Skipping obs 78 due to large residual: -3443.995 m/s
# Skipping obs 79 due to large residual: -3263.765 m/s
# Skipping obs 80 due to large residual: -3081.588 m/s
# Skipping obs 81 due to large residual: -2896.968 m/s
# Skipping obs 82 due to large residual: -2710.565 m/s
# Skipping obs 83 due to large residual: -2521.950 m/s
# Skipping obs 84 due to large residual: -2331.741 m/s
# Skipping obs 85 due to large residual: -2139.577 m/s
# Skipping obs 86 due to large residual: -1946.026 m/s
# Skipping obs 87 due to large residual: +2988.854 m/s
# Skipping obs 88 due to large residual: +3172.936 m/s
# Skipping obs 89 due to large residual: +3354.553 m/s
# Skipping obs 90 due to large residual: +3534.207 m/s
# Skipping obs 91 due to large residual: +3711.197 m/s
# Skipping obs 92 due to large residual: +3886.086 m/s
# Skipping obs 93 due to large residual: +4058.150 m/s
# Skipping obs 94 due to large residual: +4227.997 m/s
# Skipping obs 95 due to large residual: +4394.883 m/s
# Skipping obs 96 due to large residual: +4559.462 m/s
# Skipping obs 97 due to large residual: +4720.975 m/s
# Skipping obs 98 due to large residual: +4880.113 m/s
# Skipping obs 99 due to large residual: +5036.108 m/s
# Skipping obs 100 due to large residual: +5189.680 m/s
# Skipping obs 101 due to large residual: +5340.059 m/s
# Skipping obs 102 due to large residual: +5487.987 m/s
# Skipping obs 103 due to large residual: +5632.696 m/s
# Skipping obs 104 due to large residual: +5774.944 m/s
# Skipping obs 105 due to large residual: +5913.970 m/s
# Skipping obs 106 due to large residual: +6050.540 m/s
# Skipping obs 107 due to large residual: +6183.907 m/s
# Skipping obs 108 due to large residual: +6314.836 m/s
# Skipping obs 109 due to large residual: +6442.597 m/s
# Skipping obs 110 due to large residual: +6567.951 m/s
# Skipping obs 111 due to large residual: +6690.187 m/s
# Skipping obs 112 due to large residual: +6810.060 m/s
# Skipping obs 113 due to large residual: +6926.875 m/s
# Skipping obs 114 due to large residual: +7041.379 m/s
# Skipping obs 115 due to large residual: +7152.899 m/s
# Skipping obs 116 due to large residual: +7262.166 m/s
# Skipping obs 117 due to large residual: +7368.530 m/s
# Skipping obs 118 due to large residual: +7472.706 m/s
# Skipping obs 119 due to large residual: +7574.066 m/s
# Skipping obs 120 due to large residual: +7673.307 m/s
# Skipping obs 121 due to large residual: +7769.826 m/s
# Skipping obs 122 due to large residual: +7864.297 m/s
# Skipping obs 123 due to large residual: +7956.141 m/s
# Skipping obs 124 due to large residual: +8046.014 m/s
# Skipping obs 125 due to large residual: +8133.357 m/s
# Skipping obs 126 due to large residual: +8218.803 m/s
# Skipping obs 127 due to large residual: +8301.820 m/s
# Skipping obs 128 due to large residual: +8383.016 m/s
# Skipping obs 129 due to large residual: +8461.880 m/s
# Skipping obs 130 due to large residual: +8539.001 m/s
# Skipping obs 131 due to large residual: +8613.888 m/s
# Skipping obs 132 due to large residual: +8687.105 m/s
# Skipping obs 133 due to large residual: +8758.188 m/s
# Skipping obs 134 due to large residual: +8827.673 m/s
# Skipping obs 135 due to large residual: +8895.119 m/s
# Skipping obs 136 due to large residual: +8961.039 m/s
# Skipping obs 137 due to large residual: +9025.012 m/s
# Skipping obs 138 due to large residual: +9087.531 m/s
# Skipping obs 139 due to large residual: +9148.191 m/s
# Skipping obs 140 due to large residual: +9207.465 m/s
# Skipping obs 141 due to large residual: +9264.967 m/s
# Skipping obs 142 due to large residual: +9321.148 m/s
# Skipping obs 143 due to large residual: +9375.643 m/s
# Skipping obs 144 due to large residual: +9428.879 m/s
# Skipping obs 145 due to large residual: +9480.506 m/s
# Skipping obs 146 due to large residual: +9530.937 m/s
# Skipping obs 147 due to large residual: +9579.838 m/s
# Skipping obs 148 due to large residual: +9627.597 m/s
# Skipping obs 149 due to large residual: +10002.421 m/s
# Skipping obs 150 due to large residual: +10038.651 m/s
# Skipping obs 151 due to large residual: +10321.770 m/s
# Skipping obs 152 due to large residual: +10348.994 m/s
# Skipping obs 153 due to large residual: -10750.670 m/s
# Skipping obs 154 due to large residual: -10730.971 m/s
# Skipping obs 155 due to large residual: -10710.509 m/s
# Skipping obs 156 due to large residual: -10689.449 m/s
# Skipping obs 157 due to large residual: -10667.579 m/s
# Skipping obs 158 due to large residual: -10645.080 m/s
# Skipping obs 159 due to large residual: -10621.730 m/s
# Skipping obs 160 due to large residual: -10597.711 m/s
# Skipping obs 161 due to large residual: -10572.793 m/s
# Skipping obs 162 due to large residual: -10547.167 m/s
# Skipping obs 163 due to large residual: -10520.590 m/s
# Skipping obs 164 due to large residual: -10493.264 m/s
# Skipping obs 165 due to large residual: -10464.938 m/s
# Skipping obs 166 due to large residual: -10435.821 m/s
# Skipping obs 167 due to large residual: -10405.640 m/s
# Skipping obs 168 due to large residual: -10374.621 m/s
# Skipping obs 169 due to large residual: -10342.478 m/s
# Skipping obs 170 due to large residual: -10309.446 m/s
# Skipping obs 171 due to large residual: -10275.224 m/s
# Skipping obs 172 due to large residual: -10240.062 m/s
# Skipping obs 173 due to large residual: -10203.636 m/s
# Skipping obs 174 due to large residual: -10166.214 m/s
# Skipping obs 175 due to large residual: -10127.452 m/s
# Skipping obs 176 due to large residual: -10087.634 m/s
# Skipping obs 177 due to large residual: -10046.395 m/s
# Skipping obs 178 due to large residual: -10004.036 m/s
# Skipping obs 179 due to large residual: -9960.170 m/s
# Skipping obs 180 due to large residual: -9915.115 m/s
# Skipping obs 181 due to large residual: -9868.461 m/s
# Skipping obs 182 due to large residual: -9820.546 m/s
# Skipping obs 183 due to large residual: -9770.934 m/s
# Skipping obs 184 due to large residual: -9719.984 m/s
# Skipping obs 185 due to large residual: -9667.233 m/s
# Skipping obs 186 due to large residual: -9613.063 m/s
# Skipping obs 187 due to large residual: -9556.979 m/s
# Skipping obs 188 due to large residual: -9499.391 m/s
# Skipping obs 189 due to large residual: -9439.775 m/s
# Skipping obs 190 due to large residual: -9378.562 m/s
# Skipping obs 191 due to large residual: -9315.198 m/s
# Skipping obs 192 due to large residual: -9250.141 m/s
# Skipping obs 193 due to large residual: -9182.804 m/s
# Skipping obs 194 due to large residual: -9113.672 m/s
# Skipping obs 195 due to large residual: -9042.127 m/s
# Skipping obs 196 due to large residual: -8968.681 m/s
# Skipping obs 197 due to large residual: -8892.680 m/s
# Skipping obs 198 due to large residual: -8814.668 m/s
# Skipping obs 199 due to large residual: -8733.955 m/s
# Skipping obs 200 due to large residual: -8651.117 m/s
# Skipping obs 201 due to large residual: -8565.426 m/s
# Skipping obs 202 due to large residual: -8477.494 m/s
# Skipping obs 203 due to large residual: -8386.552 m/s
# Skipping obs 204 due to large residual: -8293.251 m/s
# Skipping obs 205 due to large residual: -8196.782 m/s
# Skipping obs 206 due to large residual: -8097.830 m/s
# Skipping obs 207 due to large residual: -7995.553 m/s
# Skipping obs 208 due to large residual: -7890.673 m/s
# Skipping obs 209 due to large residual: -7782.307 m/s
# Skipping obs 210 due to large residual: -7671.217 m/s
# Skipping obs 211 due to large residual: -7556.487 m/s
# Skipping obs 212 due to large residual: -7438.916 m/s
# Skipping obs 213 due to large residual: -7317.553 m/s
# Skipping obs 214 due to large residual: -7193.238 m/s
# Skipping obs 215 due to large residual: -7064.991 m/s
# Skipping obs 216 due to large residual: -6933.686 m/s
# Skipping obs 217 due to large residual: -6798.322 m/s
# Skipping obs 218 due to large residual: -6659.807 m/s
# Skipping obs 219 due to large residual: -6517.120 m/s
# Skipping obs 220 due to large residual: -6371.205 m/s
# Skipping obs 221 due to large residual: -6221.025 m/s
# Skipping obs 222 due to large residual: -6067.556 m/s
# Skipping obs 223 due to large residual: -5909.759 m/s
# Skipping obs 224 due to large residual: -5748.635 m/s
# Skipping obs 225 due to large residual: -5583.149 m/s
# Skipping obs 226 due to large residual: -5414.324 m/s
# Skipping obs 227 due to large residual: -5241.139 m/s
# Skipping obs 228 due to large residual: -5064.633 m/s
# Skipping obs 229 due to large residual: -4883.812 m/s
# Skipping obs 230 due to large residual: -4699.723 m/s
# Skipping obs 231 due to large residual: -4511.411 m/s
# Skipping obs 232 due to large residual: -4319.922 m/s
# Skipping obs 233 due to large residual: -4124.351 m/s
# Skipping obs 234 due to large residual: -3925.732 m/s
# Skipping obs 235 due to large residual: -3723.234 m/s
# Skipping obs 236 due to large residual: -3517.859 m/s
# Skipping obs 237 due to large residual: -3308.860 m/s
# Skipping obs 238 due to large residual: -3097.201 m/s
# Skipping obs 239 due to large residual: -2882.230 m/s
# Skipping obs 240 due to large residual: -2664.860 m/s
# Skipping obs 241 due to large residual: -2444.549 m/s
# Skipping obs 242 due to large residual: -2222.142 m/s
# Skipping obs 243 due to large residual: -1997.213 m/s
# Skipping obs 244 due to large residual: -1770.532 m/s
# Skipping obs 245 due to large residual: -1541.799 m/s
# Skipping obs 246 due to large residual: -1311.689 m/s
# Skipping obs 247 due to large residual: -1080.039 m/s
# Skipping obs 248 due to large residual: -847.414 m/s
# Skipping obs 249 due to large residual: -613.790 m/s
# Skipping obs 250 due to large residual: -379.616 m/s
# Skipping obs 251 due to large residual: -145.023 m/s
# Skipping obs 252 due to large residual: +89.717 m/s
# Skipping obs 253 due to large residual: +324.306 m/s
# Skipping obs 254 due to large residual: +558.570 m/s
# Skipping obs 255 due to large residual: +792.129 m/s
# Skipping obs 256 due to large residual: +1024.935 m/s
# Skipping obs 257 due to large residual: +1256.479 m/s
# Skipping obs 258 due to large residual: +1486.852 m/s
# Skipping obs 259 due to large residual: +1715.436 m/s
# Skipping obs 260 due to large residual: +1942.457 m/s
# Skipping obs 261 due to large residual: +2167.196 m/s
# Skipping obs 262 due to large residual: +2390.011 m/s
# Skipping obs 263 due to large residual: +2610.091 m/s
# Skipping obs 264 due to large residual: +2827.923 m/s
# Skipping obs 265 due to large residual: +3042.623 m/s
# Skipping obs 266 due to large residual: +3254.791 m/s
# Skipping obs 267 due to large residual: +3463.481 m/s
# Skipping obs 268 due to large residual: +3669.398 m/s
# Skipping obs 269 due to large residual: +3871.549 m/s
# Skipping obs 270 due to large residual: +4070.729 m/s
# Skipping obs 271 due to large residual: +4265.918 m/s
# Skipping obs 272 due to large residual: +4457.978 m/s
# Skipping obs 273 due to large residual: +4645.872 m/s
# Skipping obs 274 due to large residual: +4830.529 m/s
# Skipping obs 275 due to large residual: +5010.901 m/s
# Skipping obs 276 due to large residual: +5187.961 m/s
# Skipping obs 277 due to large residual: +5360.665 m/s
# Skipping obs 278 due to large residual: +5530.025 m/s
# Skipping obs 279 due to large residual: +5695.001 m/s
# Skipping obs 280 due to large residual: +5856.628 m/s
# Skipping obs 281 due to large residual: +6013.888 m/s
# Skipping obs 282 due to large residual: +6167.823 m/s
# Skipping obs 283 due to large residual: +6317.439 m/s
# Skipping obs 284 due to large residual: +6463.780 m/s
# Skipping obs 285 due to large residual: +6605.880 m/s
# Skipping obs 286 due to large residual: +6744.774 m/s
# Skipping obs 287 due to large residual: +6879.529 m/s
# Skipping obs 288 due to large residual: +7011.164 m/s
# Skipping obs 289 due to large residual: +7138.780 m/s
# Skipping obs 290 due to large residual: +7263.375 m/s
# Skipping obs 291 due to large residual: +7384.087 m/s
# Skipping obs 292 due to large residual: +7501.885 m/s
# Skipping obs 293 due to large residual: +7615.949 m/s
# Skipping obs 294 due to large residual: +7727.213 m/s
# Skipping obs 295 due to large residual: +7834.896 m/s
# Skipping obs 296 due to large residual: +7939.899 m/s
# Skipping obs 297 due to large residual: +8041.479 m/s
# Skipping obs 298 due to large residual: +8140.501 m/s
# Skipping obs 299 due to large residual: +8236.260 m/s
# Skipping obs 300 due to large residual: +8329.583 m/s
# Skipping obs 301 due to large residual: +8419.802 m/s
# Skipping obs 302 due to large residual: +8507.708 m/s
# Skipping obs 303 due to large residual: +8592.666 m/s
# Skipping obs 304 due to large residual: +8675.429 m/s
# Skipping obs 305 due to large residual: +8755.402 m/s
# Skipping obs 306 due to large residual: +8833.296 m/s
# Skipping obs 307 due to large residual: +8908.546 m/s
# Skipping obs 308 due to large residual: +8981.833 m/s
# Skipping obs 309 due to large residual: +9052.619 m/s
# Skipping obs 310 due to large residual: +9121.552 m/s
# Skipping obs 311 due to large residual: +9188.123 m/s
# Skipping obs 312 due to large residual: +9252.943 m/s
# Skipping obs 313 due to large residual: +9315.537 m/s
# Skipping obs 314 due to large residual: +9376.478 m/s
# Skipping obs 315 due to large residual: +9435.319 m/s
# Skipping obs 316 due to large residual: +9492.602 m/s
# Skipping obs 317 due to large residual: +9547.906 m/s
# Skipping obs 318 due to large residual: +9601.740 m/s
# Skipping obs 319 due to large residual: +9653.710 m/s
# Skipping obs 320 due to large residual: +9704.296 m/s
# Skipping obs 321 due to large residual: +9753.124 m/s
# Skipping obs 322 due to large residual: +9800.646 m/s
# Skipping obs 323 due to large residual: +9846.516 m/s
# Skipping obs 324 due to large residual: +9891.153 m/s
# Skipping obs 325 due to large residual: +9934.232 m/s
# Skipping obs 326 due to large residual: +9976.154 m/s
# Skipping obs 327 due to large residual: +10016.604 m/s
# Skipping obs 328 due to large residual: +10055.964 m/s
# Skipping obs 329 due to large residual: +10093.935 m/s
# Skipping obs 330 due to large residual: +10130.880 m/s
# Skipping obs 331 due to large residual: +10166.517 m/s
# Skipping obs 332 due to large residual: +10201.182 m/s
# Skipping obs 333 due to large residual: +10234.618 m/s
# Skipping obs 334 due to large residual: +10267.138 m/s
# Skipping obs 335 due to large residual: +10298.494 m/s
# Skipping obs 336 due to large residual: +10328.986 m/s
# Skipping obs 337 due to large residual: +10358.382 m/s
# Skipping obs 338 due to large residual: +10386.960 m/s
# Skipping obs 339 due to large residual: +10414.503 m/s
# Skipping obs 340 due to large residual: +10441.274 m/s
# Skipping obs 341 due to large residual: +10467.067 m/s
# Skipping obs 342 due to large residual: +10492.130 m/s
# Skipping obs 343 due to large residual: +10516.269 m/s
# Skipping obs 344 due to large residual: +10539.717 m/s
# Skipping obs 345 due to large residual: +10682.927 m/s
# Skipping obs 346 due to large residual: +10700.731 m/s
# Skipping obs 347 due to large residual: +10717.829 m/s
# Skipping obs 348 due to large residual: +10734.400 m/s
# Skipping obs 349 due to large residual: +10750.303 m/s
# Skipping obs 350 due to large residual: +10765.705 m/s
# Skipping obs 351 due to large residual: -5867.071 m/s
# Skipping obs 352 due to large residual: -5796.205 m/s
# Skipping obs 353 due to large residual: -5724.241 m/s
# Skipping obs 354 due to large residual: -5651.439 m/s
# Skipping obs 355 due to large residual: -5577.533 m/s
# Skipping obs 356 due to large residual: -5502.785 m/s
# Skipping obs 357 due to large residual: -5426.928 m/s
# Skipping obs 358 due to large residual: -5350.225 m/s
# Skipping obs 359 due to large residual: -5272.416 m/s
# Skipping obs 360 due to large residual: -5193.758 m/s
# Skipping obs 361 due to large residual: -5113.993 m/s
# Skipping obs 362 due to large residual: -5033.384 m/s
# Skipping obs 363 due to large residual: -4951.669 m/s
# Skipping obs 364 due to large residual: -4869.112 m/s
# Skipping obs 365 due to large residual: -4785.456 m/s
# Skipping obs 366 due to large residual: -4700.965 m/s
# Skipping obs 367 due to large residual: -4615.384 m/s
# Skipping obs 368 due to large residual: -4528.976 m/s
# Skipping obs 369 due to large residual: -4441.488 m/s
# Skipping obs 370 due to large residual: -4353.183 m/s
# Skipping obs 371 due to large residual: -4263.817 m/s
# Skipping obs 372 due to large residual: -4173.645 m/s
# Skipping obs 373 due to large residual: -4082.431 m/s
# Skipping obs 374 due to large residual: -3990.426 m/s
# Skipping obs 375 due to large residual: -3897.403 m/s
# Skipping obs 376 due to large residual: -3803.606 m/s
# Skipping obs 377 due to large residual: -3708.816 m/s
# Skipping obs 378 due to large residual: -3613.274 m/s
# Skipping obs 379 due to large residual: -3516.768 m/s
# Skipping obs 380 due to large residual: -3419.535 m/s
# Skipping obs 381 due to large residual: -3321.370 m/s
# Skipping obs 382 due to large residual: -3222.506 m/s
# Skipping obs 383 due to large residual: -3122.747 m/s
# Skipping obs 384 due to large residual: -3022.316 m/s
# Skipping obs 385 due to large residual: -2921.034 m/s
# Skipping obs 386 due to large residual: -2819.112 m/s
# Skipping obs 387 due to large residual: -2716.382 m/s
# Skipping obs 388 due to large residual: -2613.049 m/s
# Skipping obs 389 due to large residual: -2508.954 m/s
# Skipping obs 390 due to large residual: -2404.295 m/s
# Skipping obs 391 due to large residual: -2298.925 m/s
# Skipping obs 392 due to large residual: -2193.033 m/s
# Skipping obs 393 due to large residual: -2086.484 m/s
# Skipping obs 394 due to large residual: -1979.456 m/s
# Skipping obs 395 due to large residual: -1871.829 m/s
# Skipping obs 396 due to large residual: -1763.768 m/s
# Skipping obs 397 due to large residual: -1655.171 m/s
# Skipping obs 398 due to large residual: -1546.185 m/s
# Skipping obs 399 due to large residual: -1436.729 m/s
# Skipping obs 400 due to large residual: -1326.935 m/s
# Skipping obs 401 due to large residual: -1216.734 m/s
# Skipping obs 402 due to large residual: -1106.247 m/s
# Skipping obs 403 due to large residual: -995.424 m/s
# Skipping obs 404 due to large residual: -884.367 m/s
# Skipping obs 405 due to large residual: -773.042 m/s
# Skipping obs 406 due to large residual: -661.537 m/s
# Skipping obs 407 due to large residual: -549.838 m/s
# Skipping obs 408 due to large residual: -438.015 m/s
# Skipping obs 409 due to large residual: -326.068 m/s
# Skipping obs 410 due to large residual: -214.055 m/s
# Skipping obs 411 due to large residual: +346.049 m/s
# Skipping obs 412 due to large residual: +457.855 m/s
# Skipping obs 413 due to large residual: +569.491 m/s
# Skipping obs 414 due to large residual: +680.968 m/s
# Skipping obs 415 due to large residual: +793.404 m/s
# Skipping obs 416 due to large residual: +903.228 m/s
# Skipping obs 417 due to large residual: +1013.938 m/s
# Skipping obs 418 due to large residual: +1124.382 m/s
# Skipping obs 419 due to large residual: +1234.442 m/s
# Skipping obs 420 due to large residual: +1344.184 m/s
# Skipping obs 421 due to large residual: +1453.477 m/s
# Skipping obs 422 due to large residual: +1562.398 m/s
# Skipping obs 423 due to large residual: +1670.806 m/s
# Skipping obs 424 due to large residual: +1778.796 m/s
# Skipping obs 425 due to large residual: +1886.206 m/s
# Skipping obs 426 due to large residual: +1993.152 m/s
# Skipping obs 427 due to large residual: +2099.462 m/s
# Skipping obs 428 due to large residual: +2205.261 m/s
# Skipping obs 429 due to large residual: +2310.366 m/s
# Skipping obs 430 due to large residual: +2414.921 m/s
# Skipping obs 431 due to large residual: +2518.727 m/s
# Skipping obs 432 due to large residual: +2621.943 m/s
# Skipping obs 433 due to large residual: +2724.362 m/s
# Skipping obs 434 due to large residual: +2826.153 m/s
# Skipping obs 435 due to large residual: +2927.101 m/s
# Skipping obs 436 due to large residual: +3027.388 m/s
# Skipping obs 437 due to large residual: +3126.787 m/s
# Skipping obs 438 due to large residual: +3225.495 m/s
# Skipping obs 439 due to large residual: +3323.277 m/s
# Skipping obs 440 due to large residual: +3420.340 m/s
# Skipping obs 441 due to large residual: +3516.441 m/s
# Skipping obs 442 due to large residual: +3611.797 m/s
# Skipping obs 443 due to large residual: +3706.160 m/s
# Skipping obs 444 due to large residual: +3799.755 m/s
# Skipping obs 445 due to large residual: +3892.332 m/s
# Skipping obs 446 due to large residual: +3984.118 m/s
# Skipping obs 447 due to large residual: +4074.864 m/s
# Skipping obs 448 due to large residual: +4164.803 m/s
# Skipping obs 449 due to large residual: +4253.677 m/s
# Skipping obs 450 due to large residual: +4341.734 m/s
# Skipping obs 451 due to large residual: +4428.709 m/s
# Skipping obs 452 due to large residual: +4514.853 m/s
# Skipping obs 453 due to large residual: +4599.902 m/s
# Skipping obs 454 due to large residual: +4684.113 m/s
# Skipping obs 455 due to large residual: +4767.216 m/s
# Skipping obs 456 due to large residual: +4849.474 m/s
# Skipping obs 457 due to large residual: +4930.619 m/s
# Skipping obs 458 due to large residual: +5010.915 m/s
# Skipping obs 459 due to large residual: +5090.090 m/s
# Skipping obs 460 due to large residual: +5168.412 m/s
# Skipping obs 461 due to large residual: +5245.620 m/s
# Skipping obs 462 due to large residual: +5321.970 m/s
# Skipping obs 463 due to large residual: +5397.203 m/s
# Skipping obs 464 due to large residual: +5471.584 m/s
# Skipping obs 465 due to large residual: +5544.851 m/s
# Skipping obs 466 due to large residual: +5617.269 m/s
# Skipping obs 467 due to large residual: +5688.576 m/s
# Skipping obs 468 due to large residual: +5759.040 m/s
# Skipping obs 469 due to large residual: -6617.653 m/s
# Skipping obs 470 due to large residual: -6551.376 m/s
# Skipping obs 471 due to large residual: -6483.858 m/s
# Skipping obs 472 due to large residual: -6415.378 m/s
# Skipping obs 473 due to large residual: -6345.633 m/s
# Skipping obs 474 due to large residual: -6274.913 m/s
# Skipping obs 475 due to large residual: -6202.911 m/s
# Skipping obs 476 due to large residual: -6129.920 m/s
# Skipping obs 477 due to large residual: -6055.630 m/s
# Skipping obs 478 due to large residual: -5980.340 m/s
# Skipping obs 479 due to large residual: -5903.732 m/s
# Skipping obs 480 due to large residual: -5826.118 m/s
# Skipping obs 481 due to large residual: -5747.172 m/s
# Skipping obs 482 due to large residual: -5667.211 m/s
# Skipping obs 483 due to large residual: -5585.911 m/s
# Skipping obs 484 due to large residual: -5503.588 m/s
# Skipping obs 485 due to large residual: -5419.921 m/s
# Skipping obs 486 due to large residual: -5335.224 m/s
# Skipping obs 487 due to large residual: -5249.184 m/s
# Skipping obs 488 due to large residual: -5162.111 m/s
# Skipping obs 489 due to large residual: -5073.691 m/s
# Skipping obs 490 due to large residual: -4984.246 m/s
# Skipping obs 491 due to large residual: -4893.456 m/s
# Skipping obs 492 due to large residual: -4801.644 m/s
# Skipping obs 493 due to large residual: -4708.496 m/s
# Skipping obs 494 due to large residual: -4614.334 m/s
# Skipping obs 495 due to large residual: -4518.849 m/s
# Skipping obs 496 due to large residual: -4422.361 m/s
# Skipping obs 497 due to large residual: -4324.567 m/s
# Skipping obs 498 due to large residual: -4225.784 m/s
# Skipping obs 499 due to large residual: -4125.719 m/s
# Skipping obs 500 due to large residual: -4024.682 m/s
# Skipping obs 501 due to large residual: -3922.389 m/s
# Skipping obs 502 due to large residual: -3819.149 m/s
# Skipping obs 503 due to large residual: -3714.684 m/s
# Skipping obs 504 due to large residual: -3609.298 m/s
# Skipping obs 505 due to large residual: -3502.726 m/s
# Skipping obs 506 due to large residual: -3395.262 m/s
# Skipping obs 507 due to large residual: -3286.655 m/s
# Skipping obs 508 due to large residual: -3177.193 m/s
# Skipping obs 509 due to large residual: -3066.635 m/s
# Skipping obs 510 due to large residual: -2955.259 m/s
# Skipping obs 511 due to large residual: -2842.843 m/s
# Skipping obs 512 due to large residual: -2729.653 m/s
# Skipping obs 513 due to large residual: -2615.480 m/s
# Skipping obs 514 due to large residual: -2500.580 m/s
# Skipping obs 515 due to large residual: -2384.763 m/s
# Skipping obs 516 due to large residual: -2268.270 m/s
# Skipping obs 517 due to large residual: -2150.928 m/s
# Skipping obs 518 due to large residual: -2032.966 m/s
# Skipping obs 519 due to large residual: -1914.230 m/s
# Skipping obs 520 due to large residual: -1794.932 m/s
# Skipping obs 521 due to large residual: -1674.937 m/s
# Skipping obs 522 due to large residual: -1554.441 m/s
# Skipping obs 523 due to large residual: -1433.336 m/s
# Skipping obs 524 due to large residual: -1311.793 m/s
# Skipping obs 525 due to large residual: -1189.724 m/s
# Skipping obs 526 due to large residual: -1067.287 m/s
# Skipping obs 527 due to large residual: -944.414 m/s
# Skipping obs 528 due to large residual: -821.243 m/s
# Skipping obs 529 due to large residual: -697.729 m/s
# Skipping obs 530 due to large residual: -573.985 m/s
# Skipping obs 531 due to large residual: -449.996 m/s
# Skipping obs 532 due to large residual: -325.851 m/s
# Skipping obs 533 due to large residual: -201.554 m/s
# Skipping obs 534 due to large residual: -77.178 m/s
# Skipping obs 535 due to large residual: +47.238 m/s
# Skipping obs 536 due to large residual: +171.692 m/s
# Skipping obs 537 due to large residual: +296.087 m/s
# Skipping obs 538 due to large residual: +420.413 m/s
# Skipping obs 539 due to large residual: +544.600 m/s
# Skipping obs 540 due to large residual: +668.642 m/s
# Skipping obs 541 due to large residual: +792.451 m/s
# Skipping obs 542 due to large residual: +916.043 m/s
# Skipping obs 543 due to large residual: +1039.303 m/s
# Skipping obs 544 due to large residual: +1162.276 m/s
# Skipping obs 545 due to large residual: +1284.826 m/s
# Skipping obs 546 due to large residual: +1407.019 m/s
# Skipping obs 547 due to large residual: +1528.699 m/s
# Skipping obs 548 due to large residual: +1649.953 m/s
# Skipping obs 549 due to large residual: +1770.608 m/s
# Skipping obs 550 due to large residual: +1890.773 m/s
# Skipping obs 551 due to large residual: +2010.258 m/s
# Skipping obs 552 due to large residual: +2129.189 m/s
# Skipping obs 553 due to large residual: +2247.360 m/s
# Skipping obs 554 due to large residual: +2364.921 m/s
# Skipping obs 555 due to large residual: +2481.646 m/s
# Skipping obs 556 due to large residual: +2597.707 m/s
# Skipping obs 557 due to large residual: +2712.862 m/s
# Skipping obs 558 due to large residual: +2827.303 m/s
# Skipping obs 559 due to large residual: +2940.773 m/s
# Skipping obs 560 due to large residual: +3053.481 m/s
# Skipping obs 561 due to large residual: +3165.160 m/s
# Skipping obs 562 due to large residual: +3276.033 m/s
# Skipping obs 563 due to large residual: +3385.825 m/s
# Skipping obs 564 due to large residual: +3494.770 m/s
# Skipping obs 565 due to large residual: +3602.586 m/s
# Skipping obs 566 due to large residual: +3709.520 m/s
# Skipping obs 567 due to large residual: +3815.282 m/s
# Skipping obs 568 due to large residual: +3920.132 m/s
# Skipping obs 569 due to large residual: +4023.772 m/s
# Skipping obs 570 due to large residual: +4126.474 m/s
# Skipping obs 571 due to large residual: +4227.933 m/s
# Skipping obs 572 due to large residual: +4328.431 m/s
# Skipping obs 573 due to large residual: +4427.660 m/s
# Skipping obs 574 due to large residual: +4525.909 m/s
# Skipping obs 575 due to large residual: +4622.866 m/s
# Skipping obs 576 due to large residual: +4718.829 m/s
# Skipping obs 577 due to large residual: +4813.482 m/s
# Skipping obs 578 due to large residual: +4907.130 m/s
# Skipping obs 579 due to large residual: +4999.455 m/s
# Skipping obs 580 due to large residual: +5090.765 m/s
# Skipping obs 581 due to large residual: +5180.747 m/s
# Skipping obs 582 due to large residual: +5269.709 m/s
# Skipping obs 583 due to large residual: +5357.337 m/s
# Skipping obs 584 due to large residual: +5443.943 m/s
# Skipping obs 585 due to large residual: +5529.215 m/s
# Skipping obs 586 due to large residual: +5613.468 m/s
# Skipping obs 587 due to large residual: +5696.388 m/s
# Skipping obs 588 due to large residual: +5778.291 m/s
# Skipping obs 589 due to large residual: +5858.870 m/s
# Skipping obs 590 due to large residual: +5938.437 m/s
# Skipping obs 591 due to large residual: +6016.689 m/s
# Skipping obs 592 due to large residual: +6093.938 m/s
# Skipping obs 593 due to large residual: +6169.882 m/s
# Skipping obs 594 due to large residual: +6244.834 m/s
# Skipping obs 595 due to large residual: +6318.497 m/s
# Skipping obs 596 due to large residual: +6391.179 m/s
# Skipping obs 597 due to large residual: +6462.587 m/s
# Skipping obs 598 due to large residual: +6533.027 m/s
# Skipping obs 599 due to large residual: +6602.213 m/s
# Skipping obs 600 due to large residual: +6670.446 m/s
# Skipping obs 601 due to large residual: +6737.443 m/s
# Skipping obs 602 due to large residual: +6803.505 m/s
# Skipping obs 603 due to large residual: +6868.352 m/s
# Skipping obs 604 due to large residual: +6932.278 m/s
# Skipping obs 605 due to large residual: +6995.015 m/s
# Skipping obs 606 due to large residual: +7056.848 m/s
# Skipping obs 607 due to large residual: +7117.515 m/s
# Skipping obs 608 due to large residual: +7177.297 m/s
# Skipping obs 609 due to large residual: +7235.937 m/s
# Skipping obs 610 due to large residual: +7293.712 m/s
# Skipping obs 611 due to large residual: -10949.260 m/s
# Skipping obs 612 due to large residual: -10930.172 m/s
# Skipping obs 613 due to large residual: -10910.250 m/s
# Skipping obs 614 due to large residual: -10889.673 m/s
# Skipping obs 615 due to large residual: -10868.210 m/s
# Skipping obs 616 due to large residual: -10846.051 m/s
# Skipping obs 617 due to large residual: -10822.950 m/s
# Skipping obs 618 due to large residual: -10799.108 m/s
# Skipping obs 619 due to large residual: -10774.263 m/s
# Skipping obs 620 due to large residual: -10748.630 m/s
# Skipping obs 621 due to large residual: -10721.929 m/s
# Skipping obs 622 due to large residual: -10694.386 m/s
# Skipping obs 623 due to large residual: -10665.705 m/s
# Skipping obs 624 due to large residual: -10636.126 m/s
# Skipping obs 625 due to large residual: -10605.334 m/s
# Skipping obs 626 due to large residual: -10573.583 m/s
# Skipping obs 627 due to large residual: -10540.536 m/s
# Skipping obs 628 due to large residual: -10506.464 m/s
# Skipping obs 629 due to large residual: -10471.008 m/s
# Skipping obs 630 due to large residual: -10434.459 m/s
# Skipping obs 631 due to large residual: -10396.426 m/s
# Skipping obs 632 due to large residual: -10357.224 m/s
# Skipping obs 633 due to large residual: -10316.438 m/s
# Skipping obs 634 due to large residual: -10274.399 m/s
# Skipping obs 635 due to large residual: -10230.664 m/s
# Skipping obs 636 due to large residual: -10185.589 m/s
# Skipping obs 637 due to large residual: -10138.696 m/s
# Skipping obs 638 due to large residual: -10090.367 m/s
# Skipping obs 639 due to large residual: -10040.093 m/s
# Skipping obs 640 due to large residual: -9988.281 m/s
# Skipping obs 641 due to large residual: -9934.383 m/s
# Skipping obs 642 due to large residual: -9878.836 m/s
# Skipping obs 643 due to large residual: -9821.055 m/s
# Skipping obs 644 due to large residual: -9761.507 m/s
# Skipping obs 645 due to large residual: -9699.566 m/s
# Skipping obs 646 due to large residual: -9635.731 m/s
# Skipping obs 647 due to large residual: -9569.330 m/s
# Skipping obs 648 due to large residual: -9500.901 m/s
# Skipping obs 649 due to large residual: -9429.726 m/s
# Skipping obs 650 due to large residual: -9356.379 m/s
# Skipping obs 651 due to large residual: -9280.091 m/s
# Skipping obs 652 due to large residual: -9201.478 m/s
# Skipping obs 653 due to large residual: -9119.722 m/s
# Skipping obs 654 due to large residual: -9035.481 m/s
# Skipping obs 655 due to large residual: -8947.879 m/s
# Skipping obs 656 due to large residual: -8857.623 m/s
# Skipping obs 657 due to large residual: -8763.785 m/s
# Skipping obs 658 due to large residual: -8667.116 m/s
# Skipping obs 659 due to large residual: -8566.629 m/s
# Skipping obs 660 due to large residual: -8463.133 m/s
# Skipping obs 661 due to large residual: -8355.576 m/s
# Skipping obs 662 due to large residual: -8244.824 m/s
# Skipping obs 663 due to large residual: -8129.770 m/s
# Skipping obs 664 due to large residual: -8011.329 m/s
# Skipping obs 665 due to large residual: -7888.341 m/s
# Skipping obs 666 due to large residual: -7761.782 m/s
# Skipping obs 667 due to large residual: -7630.431 m/s
# Skipping obs 668 due to large residual: -7495.327 m/s
# Skipping obs 669 due to large residual: -7355.198 m/s
# Skipping obs 670 due to large residual: -7211.140 m/s
# Skipping obs 671 due to large residual: -7061.839 m/s
# Skipping obs 672 due to large residual: -6908.450 m/s
# Skipping obs 673 due to large residual: -6749.618 m/s
# Skipping obs 674 due to large residual: -6586.559 m/s
# Skipping obs 675 due to large residual: -6417.892 m/s
# Skipping obs 676 due to large residual: -6244.883 m/s
# Skipping obs 677 due to large residual: -6066.142 m/s
# Skipping obs 678 due to large residual: -5882.980 m/s
# Skipping obs 679 due to large residual: -5694.010 m/s
# Skipping obs 680 due to large residual: -5500.587 m/s
# Skipping obs 681 due to large residual: -5301.337 m/s
# Skipping obs 682 due to large residual: -5097.650 m/s
# Skipping obs 683 due to large residual: -4888.198 m/s
# Skipping obs 684 due to large residual: -4674.381 m/s
# Skipping obs 685 due to large residual: -4454.940 m/s
# Skipping obs 686 due to large residual: -4231.276 m/s
# Skipping obs 687 due to large residual: -4002.221 m/s
# Skipping obs 688 due to large residual: -3769.158 m/s
# Skipping obs 689 due to large residual: -3531.031 m/s
# Skipping obs 690 due to large residual: -3289.190 m/s
# Skipping obs 691 due to large residual: -3042.715 m/s
# Skipping obs 692 due to large residual: -2792.893 m/s
# Skipping obs 693 due to large residual: -2538.972 m/s
# Skipping obs 694 due to large residual: -2282.147 m/s
# Skipping obs 695 due to large residual: -2021.854 m/s
# Skipping obs 696 due to large residual: -1759.170 m/s
# Skipping obs 697 due to large residual: -1493.728 m/s
# Skipping obs 698 due to large residual: -1226.473 m/s
# Skipping obs 699 due to large residual: -957.248 m/s
# Skipping obs 700 due to large residual: -686.832 m/s
# Skipping obs 701 due to large residual: -415.285 m/s
# Skipping obs 702 due to large residual: -143.204 m/s
# Skipping obs 703 due to large residual: +129.123 m/s
# Skipping obs 704 due to large residual: +401.347 m/s
# Skipping obs 705 due to large residual: +672.938 m/s
# Skipping obs 706 due to large residual: +943.728 m/s
# Skipping obs 707 due to large residual: +1213.041 m/s
# Skipping obs 708 due to large residual: +1480.908 m/s
# Skipping obs 709 due to large residual: +1746.481 m/s
# Skipping obs 710 due to large residual: +2010.002 m/s
# Skipping obs 711 due to large residual: +2270.470 m/s
# Skipping obs 712 due to large residual: +2528.336 m/s
# Skipping obs 713 due to large residual: +2782.472 m/s
# Skipping obs 714 due to large residual: +3033.518 m/s
# Skipping obs 715 due to large residual: +3280.245 m/s
# Skipping obs 716 due to large residual: +3523.471 m/s
# Skipping obs 717 due to large residual: +3761.886 m/s
# Skipping obs 718 due to large residual: +3996.463 m/s
# Skipping obs 719 due to large residual: +4225.844 m/s
# Skipping obs 720 due to large residual: +4451.128 m/s
# Skipping obs 721 due to large residual: +4670.925 m/s
# Skipping obs 722 due to large residual: +4886.444 m/s
# Skipping obs 723 due to large residual: +5096.285 m/s
# Skipping obs 724 due to large residual: +5301.732 m/s
# Skipping obs 725 due to large residual: +5501.393 m/s
# Skipping obs 726 due to large residual: +5696.615 m/s
# Skipping obs 727 due to large residual: +5886.025 m/s
# Skipping obs 728 due to large residual: +6071.001 m/s
# Skipping obs 729 due to large residual: +6250.205 m/s
# Skipping obs 730 due to large residual: +6425.028 m/s
# Skipping obs 731 due to large residual: +6594.179 m/s
# Skipping obs 732 due to large residual: +6759.043 m/s
# Skipping obs 733 due to large residual: +6918.375 m/s
# Skipping obs 734 due to large residual: +7073.546 m/s
# Skipping obs 735 due to large residual: +7223.367 m/s
# Skipping obs 736 due to large residual: +7369.175 m/s
# Skipping obs 737 due to large residual: +7509.838 m/s
# Skipping obs 738 due to large residual: +7646.653 m/s
# Skipping obs 739 due to large residual: +7778.553 m/s
# Skipping obs 740 due to large residual: +7906.781 m/s
# Skipping obs 741 due to large residual: +8030.328 m/s
# Skipping obs 742 due to large residual: +8150.390 m/s
# Skipping obs 743 due to large residual: +8266.016 m/s
# Skipping obs 744 due to large residual: +8378.343 m/s
# Skipping obs 745 due to large residual: +8486.477 m/s
# Skipping obs 746 due to large residual: +8591.500 m/s
# Skipping obs 747 due to large residual: +8692.574 m/s
# Skipping obs 748 due to large residual: +8790.720 m/s
# Skipping obs 749 due to large residual: +8885.154 m/s
# Skipping obs 750 due to large residual: +8976.836 m/s
# Skipping obs 751 due to large residual: +9065.037 m/s
# Skipping obs 752 due to large residual: +9150.662 m/s
# Skipping obs 753 due to large residual: +9233.022 m/s
# Skipping obs 754 due to large residual: +9312.970 m/s
# Skipping obs 755 due to large residual: +9389.867 m/s
# Skipping obs 756 due to large residual: +9464.506 m/s
# Skipping obs 757 due to large residual: +9536.293 m/s
# Skipping obs 758 due to large residual: +9605.973 m/s
# Skipping obs 759 due to large residual: +9672.987 m/s
# Skipping obs 760 due to large residual: +9738.032 m/s
# Skipping obs 761 due to large residual: +9800.591 m/s
# Skipping obs 762 due to large residual: +9861.310 m/s
# Skipping obs 763 due to large residual: +9919.709 m/s
# Skipping obs 764 due to large residual: +9976.393 m/s
# Skipping obs 765 due to large residual: +10030.909 m/s
# Skipping obs 766 due to large residual: +10083.824 m/s
# Skipping obs 767 due to large residual: +10134.718 m/s
# Skipping obs 768 due to large residual: +10184.116 m/s
# Skipping obs 769 due to large residual: +10231.628 m/s
# Skipping obs 770 due to large residual: +10277.744 m/s
# Skipping obs 771 due to large residual: +10322.098 m/s
# Skipping obs 772 due to large residual: +10365.149 m/s
# Skipping obs 773 due to large residual: +10406.554 m/s
# Skipping obs 774 due to large residual: +10446.739 m/s
# Skipping obs 775 due to large residual: +10485.389 m/s
# Skipping obs 776 due to large residual: +10522.899 m/s
# Skipping obs 777 due to large residual: +10558.972 m/s
# Skipping obs 778 due to large residual: +10593.978 m/s
# Skipping obs 779 due to large residual: +10627.640 m/s
# Skipping obs 780 due to large residual: +10660.306 m/s
# Skipping obs 781 due to large residual: +10691.710 m/s
# Skipping obs 782 due to large residual: +10722.182 m/s
# Skipping obs 783 due to large residual: +10751.472 m/s
# Skipping obs 784 due to large residual: +10779.887 m/s
# Skipping obs 785 due to large residual: +10807.197 m/s
# Skipping obs 786 due to large residual: +10833.685 m/s
# Skipping obs 787 due to large residual: +10859.134 m/s
# Skipping obs 788 due to large residual: +10883.812 m/s
# Skipping obs 789 due to large residual: +10907.515 m/s
# Skipping obs 790 due to large residual: +10930.493 m/s
# Skipping obs 791 due to large residual: +10952.555 m/s
# Skipping obs 792 due to large residual: +10973.937 m/s
# Skipping obs 793 due to large residual: +10994.453 m/s
# Skipping obs 794 due to large residual: +11014.329 m/s
# Skipping obs 795 due to large residual: +11033.394 m/s
# Skipping obs 796 due to large residual: +11051.853 m/s
# Skipping obs 797 due to large residual: +11069.548 m/s
# Skipping obs 798 due to large residual: +11086.672 m/s
# Skipping obs 799 due to large residual: +11103.073 m/s
# Skipping obs 800 due to large residual: +11118.937 m/s
# Skipping obs 801 due to large residual: +11134.119 m/s
# Skipping obs 802 due to large residual: +11148.794 m/s
# Skipping obs 803 due to large residual: +11162.821 m/s
# Skipping obs 804 due to large residual: +11176.369 m/s
# Skipping obs 805 due to large residual: +11189.307 m/s
# Skipping obs 806 due to large residual: +11201.791 m/s
# Skipping obs 807 due to large residual: +11213.695 m/s
# Skipping obs 808 due to large residual: +11225.170 m/s
# Skipping obs 809 due to large residual: -8623.033 m/s
# Skipping obs 810 due to large residual: -8564.358 m/s
# Skipping obs 811 due to large residual: -8504.164 m/s
# Skipping obs 812 due to large residual: -8442.789 m/s
# Skipping obs 813 due to large residual: -8379.841 m/s
# Skipping obs 814 due to large residual: -8315.670 m/s
# Skipping obs 815 due to large residual: -8249.868 m/s
# Skipping obs 816 due to large residual: -8182.798 m/s
# Skipping obs 817 due to large residual: -8114.040 m/s
# Skipping obs 818 due to large residual: -8043.971 m/s
# Skipping obs 819 due to large residual: -7972.158 m/s
# Skipping obs 820 due to large residual: -7898.989 m/s
# Skipping obs 821 due to large residual: -7824.019 m/s
# Skipping obs 822 due to large residual: -7747.652 m/s
# Skipping obs 823 due to large residual: -7669.425 m/s
# Skipping obs 824 due to large residual: -7589.757 m/s
# Skipping obs 825 due to large residual: -7508.179 m/s
# Skipping obs 826 due to large residual: -7425.117 m/s
# Skipping obs 827 due to large residual: -7340.089 m/s
# Skipping obs 828 due to large residual: -7253.540 m/s
# Skipping obs 829 due to large residual: -7164.973 m/s
# Skipping obs 830 due to large residual: -7074.847 m/s
# Skipping obs 831 due to large residual: -6982.656 m/s
# Skipping obs 832 due to large residual: -6888.871 m/s
# Skipping obs 833 due to large residual: -6792.977 m/s
# Skipping obs 834 due to large residual: -6695.455 m/s
# Skipping obs 835 due to large residual: -6595.785 m/s
# Skipping obs 836 due to large residual: -6494.460 m/s
# Skipping obs 837 due to large residual: -6390.952 m/s
# Skipping obs 838 due to large residual: -6285.765 m/s
# Skipping obs 839 due to large residual: -6178.368 m/s
# Skipping obs 840 due to large residual: -6069.272 m/s
# Skipping obs 841 due to large residual: -5957.945 m/s
# Skipping obs 842 due to large residual: -5844.908 m/s
# Skipping obs 843 due to large residual: -5729.627 m/s
# Skipping obs 844 due to large residual: -5612.628 m/s
# Skipping obs 845 due to large residual: -5493.383 m/s
# Skipping obs 846 due to large residual: -5372.421 m/s
# Skipping obs 847 due to large residual: -5249.219 m/s
# Skipping obs 848 due to large residual: -5124.310 m/s
# Skipping obs 849 due to large residual: -4997.178 m/s
# Skipping obs 850 due to large residual: -4868.357 m/s
# Skipping obs 851 due to large residual: -4737.343 m/s
# Skipping obs 852 due to large residual: -4604.668 m/s
# Skipping obs 853 due to large residual: -4469.843 m/s
# Skipping obs 854 due to large residual: -4333.393 m/s
# Skipping obs 855 due to large residual: -4194.850 m/s
# Skipping obs 856 due to large residual: -4054.730 m/s
# Skipping obs 857 due to large residual: -3912.586 m/s
# Skipping obs 858 due to large residual: -3768.926 m/s
# Skipping obs 859 due to large residual: -3623.327 m/s
# Skipping obs 860 due to large residual: -3476.281 m/s
# Skipping obs 861 due to large residual: -3327.395 m/s
# Skipping obs 862 due to large residual: -3177.146 m/s
# Skipping obs 863 due to large residual: -3025.169 m/s
# Skipping obs 864 due to large residual: -2871.922 m/s
# Skipping obs 865 due to large residual: -2717.078 m/s
# Skipping obs 866 due to large residual: -2561.067 m/s
# Skipping obs 867 due to large residual: -2403.602 m/s
# Skipping obs 868 due to large residual: -2245.084 m/s
# Skipping obs 869 due to large residual: -2085.270 m/s
# Skipping obs 870 due to large residual: -1924.526 m/s
# Skipping obs 871 due to large residual: -1762.655 m/s
# Skipping obs 872 due to large residual: -1599.989 m/s
# Skipping obs 873 due to large residual: -1436.374 m/s
# Skipping obs 874 due to large residual: -1272.106 m/s
# Skipping obs 875 due to large residual: -1107.079 m/s
# Skipping obs 876 due to large residual: -941.547 m/s
# Skipping obs 877 due to large residual: -775.452 m/s
# Skipping obs 878 due to large residual: -609.006 m/s
# Skipping obs 879 due to large residual: -442.201 m/s
# Skipping obs 880 due to large residual: -275.201 m/s
# Skipping obs 881 due to large residual: -108.065 m/s
# Skipping obs 882 due to large residual: +59.137 m/s
# Skipping obs 883 due to large residual: +226.269 m/s
# Skipping obs 884 due to large residual: +393.277 m/s
# Skipping obs 885 due to large residual: +560.017 m/s
# Skipping obs 886 due to large residual: +726.477 m/s
# Skipping obs 887 due to large residual: +892.465 m/s
# Skipping obs 888 due to large residual: +1058.016 m/s
# Skipping obs 889 due to large residual: +1222.895 m/s
# Skipping obs 890 due to large residual: +1387.186 m/s
# Skipping obs 891 due to large residual: +1550.612 m/s
# Skipping obs 892 due to large residual: +1713.304 m/s
# Skipping obs 893 due to large residual: +1874.945 m/s
# Skipping obs 894 due to large residual: +2035.717 m/s
# Skipping obs 895 due to large residual: +2195.262 m/s
# Skipping obs 896 due to large residual: +2353.806 m/s
# Skipping obs 897 due to large residual: +2510.964 m/s
# Skipping obs 898 due to large residual: +2667.001 m/s
# Skipping obs 899 due to large residual: +2821.500 m/s
# Skipping obs 900 due to large residual: +2974.768 m/s
# Skipping obs 901 due to large residual: +3126.364 m/s
# Skipping obs 902 due to large residual: +3276.630 m/s
# Skipping obs 903 due to large residual: +3425.100 m/s
# Skipping obs 904 due to large residual: +3572.154 m/s
# Skipping obs 905 due to large residual: +3717.305 m/s
# Skipping obs 906 due to large residual: +3860.964 m/s
# Skipping obs 907 due to large residual: +4002.626 m/s
# Skipping obs 908 due to large residual: +4142.732 m/s
# Skipping obs 909 due to large residual: +4280.765 m/s
# Skipping obs 910 due to large residual: +4417.186 m/s
# Skipping obs 911 due to large residual: +4551.472 m/s
# Skipping obs 912 due to large residual: +4684.105 m/s
# Skipping obs 913 due to large residual: +4814.550 m/s
# Skipping obs 914 due to large residual: +4943.311 m/s
# Skipping obs 915 due to large residual: +5069.849 m/s
# Skipping obs 916 due to large residual: +5194.678 m/s
# Skipping obs 917 due to large residual: +5317.264 m/s
# Skipping obs 918 due to large residual: +5438.125 m/s
# Skipping obs 919 due to large residual: +5556.731 m/s
# Skipping obs 920 due to large residual: +5673.608 m/s
# Skipping obs 921 due to large residual: +5788.228 m/s
# Skipping obs 922 due to large residual: +5901.122 m/s
# Skipping obs 923 due to large residual: +6011.766 m/s
# Skipping obs 924 due to large residual: +6120.694 m/s
# Skipping obs 925 due to large residual: +6227.391 m/s
# Skipping obs 926 due to large residual: +6332.387 m/s
# Skipping obs 927 due to large residual: +6435.176 m/s
# Skipping obs 928 due to large residual: +6536.288 m/s
# Skipping obs 929 due to large residual: +6635.221 m/s
# Skipping obs 930 due to large residual: +6732.505 m/s
# Skipping obs 931 due to large residual: +6827.648 m/s
# Skipping obs 932 due to large residual: +6921.172 m/s
# Skipping obs 933 due to large residual: +7012.597 m/s
# Skipping obs 934 due to large residual: +7102.436 m/s
# Skipping obs 935 due to large residual: +7190.224 m/s
# Skipping obs 936 due to large residual: +7276.462 m/s
# Skipping obs 937 due to large residual: +7360.699 m/s
# Skipping obs 938 due to large residual: +7443.424 m/s
# Skipping obs 939 due to large residual: +7524.202 m/s
# Skipping obs 940 due to large residual: +7603.509 m/s
# Skipping obs 941 due to large residual: +7680.923 m/s
# Skipping obs 942 due to large residual: +7756.909 m/s
# Skipping obs 943 due to large residual: +7831.056 m/s
# Skipping obs 944 due to large residual: +7903.820 m/s
# Skipping obs 945 due to large residual: +7974.801 m/s
# Skipping obs 946 due to large residual: +8044.443 m/s
# Skipping obs 947 due to large residual: +8112.360 m/s
# Skipping obs 948 due to large residual: +8178.981 m/s
# Skipping obs 949 due to large residual: +8243.936 m/s
# Skipping obs 950 due to large residual: +8307.636 m/s
# Skipping obs 951 due to large residual: +8369.730 m/s
# Skipping obs 952 due to large residual: +8430.615 m/s
# Skipping obs 953 due to large residual: +8489.946 m/s
# Skipping obs 954 due to large residual: +8548.114 m/s
# Skipping obs 955 due to large residual: +8604.782 m/s
# Skipping obs 956 due to large residual: +8660.329 m/s
# Skipping obs 957 due to large residual: +8714.436 m/s
# Skipping obs 958 due to large residual: +8767.459 m/s
# Skipping obs 959 due to large residual: +8819.095 m/s
# Skipping obs 960 due to large residual: +8869.693 m/s

# %%
# Section 6.3 – Final parameter estimates and comparison to initial guess

final_xyz = x[0:3]
initial_xyz = x0[0:3]
delta_xyz = final_xyz - initial_xyz
delta_norm = np.linalg.norm(delta_xyz)

print("\n[RESULT] Beacon estimated position vs initial (XYZ):")
print(f"  X = {final_xyz[0]:+15.3f} m   | X_init = {initial_xyz[0]:+15.3f} m   | ΔX = {delta_xyz[0]:+15.3f} m")
print(f"  Y = {final_xyz[1]:+15.3f} m   | Y_init = {initial_xyz[1]:+15.3f} m   | ΔY = {delta_xyz[1]:+15.3f} m")
print(f"  Z = {final_xyz[2]:+15.3f} m   | Z_init = {initial_xyz[2]:+15.3f} m   | ΔZ = {delta_xyz[2]:+15.3f} m")

print(f"\n[RESULT] Total position error (‖Δr‖): {delta_norm:.3f} m")
print(f"\n[RESULT] Sigma0 A-Posteriori        : {sigma_hat0:.2f} [m/s]")

#print("\n[RESULT] Per-Pass estimated values:")
#for ps in range(Np):
#    print(f"Pass Nr. {ps+1} dF={x[3+ps]:.6f} dT={x[3+Np+ps]:+.3f}")
# Out:
# [RESULT] Beacon estimated position vs initial (XYZ):
#   X =    +4595911.831 m   | X_init =    +4595212.885 m   | ΔX =        +698.946 m
#   Y =    +2038218.575 m   | Y_init =    +2039474.042 m   | ΔY =       -1255.467 m
#   Z =    +3912691.233 m   | Z_init =    +3912618.015 m   | ΔZ =         +73.218 m
#
# [RESULT] Total position error (‖Δr‖): 1438.778 m
#
# [RESULT] Sigma0 A-Posteriori        : 2.55 [m/s]
